# %%
import cv2
import matplotlib.pyplot as plt
imagen = cv2.imread("C:/Users/DanielC/Documents/MAESTRIA CYBERSEGURIDAD/PROYECTO/imagen.png")
imagen
plt.imshow(imagen)
pic_red = imagen.copy()
#plt.imshow(pic_red[:,:,0])
#plt.imshow(pic_red[:,:,0], cmap='gray')

# %%
plt.imshow(pic_red [:,:,0])

# %%
pic_red [:,:,1]=0
plt.imshow(pic_red)

# %%
pic_red [:,:,0]=0
plt.imshow(pic_red)

# %%
plt.imshow(pic_red [:,:,0], cmap='gray')
