# %%
import glob #importamos la libreria
import cv2 #importamos la libreria
import matplotlib.pyplot as plt #importamos la libreria
file = 'C:/Users/DanielC/Documents/MAESTRIA CYBERSEGURIDAD/PROYECTO/train/CLASS_02/05-CAPTURE_20220421_053226_860.png'
pict = cv2.imread(file)
plt.imshow(pict)

# %%
file = 'C:/Users/DanielC/Documents/MAESTRIA CYBERSEGURIDAD/PROYECTO/train/CLASS_02/*.png'
glob.glob(file)
images = [cv2.imread(image) for image in glob.glob(file)]

# %%
type (images)

# %%
len (images)

# %%
plt.imshow(images[10])

# %%
rows = 2
cols = 3
for i in range(0, len(images), rows*cols):
    fig = plt.figure(figsize=(7,8))
    for j in range (0, rows*cols):
        fig.add_subplot(rows, cols, j+1)
        plt.imshow(images[i+j])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [75], in <cell line: 3>()
#       5 for j in range (0, rows*cols):
#       6     fig.add_subplot(rows, cols, j+1)
# ----> 7     plt.imshow(images[i+j])
#       8 plt.show()
#
# IndexError: list index out of range

# %%
file1 = 'C:/Users/DanielC/Documents/MAESTRIA CYBERSEGURIDAD/PROYECTO/train/CLASS_03/*.png'
glob.glob(file1)
images1 = [cv2.imread(image) for image in glob.glob(file1)]
type (images1)
len (images1)

# %%
plt.imshow(images1[10])

# %%
file2 = 'C:/Users/DanielC/Documents/MAESTRIA CYBERSEGURIDAD/PROYECTO/train/CLASS_04/*.png'
glob.glob(file2)
images2 = [cv2.imread(image) for image in glob.glob(file2)]
type (images2)
len (images2)

# %%
plt.imshow(images2[10])

# %%
file3 = 'C:/Users/DanielC/Documents/MAESTRIA CYBERSEGURIDAD/PROYECTO/train/CLASS_05/*.png'
glob.glob(file3)
images3 = [cv2.imread(image) for image in glob.glob(file3)]
type (images3)
len (images3)

# %%
plt.imshow(images3[10])

# %%
file4 = 'C:/Users/DanielC/Documents/MAESTRIA CYBERSEGURIDAD/PROYECTO/train/CLASS_06/*.png'
glob.glob(file4)
images4 = [cv2.imread(image) for image in glob.glob(file4)]
type (images4)
len (images4)

# %%
plt.imshow(images4[10])

# %%
file5 = 'C:/Users/DanielC/Documents/MAESTRIA CYBERSEGURIDAD/PROYECTO/train/CLASS_07/*.png'
glob.glob(file5)
images5 = [cv2.imread(image) for image in glob.glob(file5)]
type (images5)
len (images5)

# %%
plt.imshow(images5[10])

# %%
file6 = 'C:/Users/DanielC/Documents/MAESTRIA CYBERSEGURIDAD/PROYECTO/train/CLASS_08/*.png'
glob.glob(file6)
images6 = [cv2.imread(image) for image in glob.glob(file6)]
type (images6)
len (images6)

# %%
plt.imshow(images6[10])
