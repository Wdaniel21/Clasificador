# %%
#from tkinter import * #importamos la libreria
#from PIL import ImageTk, Image #importamos
#imagen = Image.open("imagen.png") #definimos variable "imagen" y la obtenemos de su ubicacion
#imagen = imagen.resize((28,28), Image.ANTIALIAS) #refuccion de tamaño, ANTIALIAS=metodo de renderizacion
#img = ImageTk.PhotoImage(imagen) #declaramos la variable y llamamos metodo
#lbl_img = Label(ventana, imagen = img)
#lbl_img.pack()
# Out:
# hello

# %%
#from matplotlib import pyplot as plt
import glob #importamos la libreria
import cv2 #importamos la libreria
import matplotlib.pyplot as plt #importamos la libreria
img = 'C:/Users/DanielC/Documents/MAESTRIA CYBERSEGURIDAD/PROYECTO/test/CLASS_02/*.png' #accedemos a la ruta donde se encuentran las imagenes
glob.glob(img) #generamos un listado
images = [cv2.imread(image) for image in glob.glob(img)] #leemos el listado
type (images) #verificamos listado
len (images) #cantidad de imagenes
plt.imshow(images[32]) #visualizamos una imagen en especifico
fig = plt.figure(figsize=(0.2,0.2)) #modificamos el tamaño de esa imagen
